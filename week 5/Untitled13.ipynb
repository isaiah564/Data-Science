# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
B=pd.read_csv('C:\\Users\\Admin\\Downloads\\BaseballSalaries.csv')
B.head()
# Out:
#               Name                  Team       Position       Salary  \
# 0       Mike Trout    Los Angeles Angels     Outfielder  $34,083,333
# 1  Clayton Kershaw   Los Angeles Dodgers        Pitcher  $34,000,000
# 2     Zack Greinke  Arizona Diamondbacks        Pitcher  $31,954,483
# 3   Miguel Cabrera        Detroit Tigers  First Baseman  $30,000,000
# 4      David Price        Boston Red Sox        Pitcher  $30,000,000
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN

# %%
B.isnull().sum()
# Out:
# Name            0
# Team            0
# Position        0
# Salary          0
# Unnamed: 4    877
# Unnamed: 5    877
# Unnamed: 6    877
# Unnamed: 7    877
# Unnamed: 8    877
# dtype: int64

# %%
s=B[['Name','Team','Salary','Position',]]

# %%
s.head()
# Out:
#               Name                  Team       Salary       Position
# 0       Mike Trout    Los Angeles Angels  $34,083,333     Outfielder
# 1  Clayton Kershaw   Los Angeles Dodgers  $34,000,000        Pitcher
# 2     Zack Greinke  Arizona Diamondbacks  $31,954,483        Pitcher
# 3   Miguel Cabrera        Detroit Tigers  $30,000,000  First Baseman
# 4      David Price        Boston Red Sox  $30,000,000        Pitcher

# %%
s.describe()
# Out:
#                 Name           Team    Salary Position
# count            877            877       877      877
# unique           876             30       447        8
# top     Jose Ramirez  Texas Rangers  $545,000  Pitcher
# freq               2             32        44      461

# %%
s['Position'].unique()
# Out:
# array(['Outfielder', 'Pitcher', 'First Baseman', 'Second Baseman',
#        'Third Baseman', 'Catcher', 'Shortstop', 'Designated Hitter'],
#       dtype=object)

# %%
plt.plot(s['Salary'],s['Position'])

# %%
values=s['Salary']
labels=s['Position']

bars=plt.bar(labels,values)

bars[0].set_hatch('*')
bars[1].set_hatch('+')

plt.figure(figsize=(3,7),dpi=400)
plt.show()
