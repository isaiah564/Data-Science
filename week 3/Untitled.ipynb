# %%
import pandas as pd
import numpy as np

# %%
f=pd.read_csv('C:\\Users\\Admin\\Downloads\\DiseaseOutbreaks\\Outbreaks.csv')
f.head()
# Out:
#    Unnamed: 0      Country iso2 iso3  Year  \
# 0           1  Afghanistan   AF  AFG  2000
# 1           2  Afghanistan   AF  AFG  2002
# 2           3  Afghanistan   AF  AFG  1998
# 3           4  Afghanistan   AF  AFG  1999
# 4           5  Afghanistan   AF  AFG  2000
#
#                                               icd10n  \
# 0  Arthropod-borne viral fevers and viral haemorr...
# 1                     Intestinal infectious diseases
# 2                     Intestinal infectious diseases
# 3                         Codes for special purposes
# 4                     Intestinal infectious diseases
#
#                                              icd103n  \
# 0               Unspecified viral haemorrhagic fever
# 1  Other gastroenteritis and colitis of infectiou...
# 2                                            Cholera
# 3  Provisional assignment of new diseases of unce...
# 4                                            Cholera
#
# ...

# %%
s=pd.read_csv('C:\\Users\\Admin\\Downloads\\data.csv')
s.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %%
f.isnull().sum()
# Out:
# Unnamed: 0      0
# Country         0
# iso2            4
# iso3            0
# Year            0
# icd10n          0
# icd103n         0
# icd104n         0
# icd10c          0
# icd103c         0
# icd104c         0
# icd11c1         0
# icd11c2         0
# icd11c3         0
# icd11l1         0
# icd11l2        12
# icd11l3        12
# Disease         0
# DONs            0
# Definition    100
# dtype: int64

# %%
f.describe()
# Out:
#         Unnamed: 0         Year
# count  2227.000000  2227.000000
# mean   1114.000000  2012.122137
# std     643.023846     8.560780
# min       1.000000  1996.000000
# 25%     557.500000  2005.000000
# 50%    1114.000000  2014.000000
# 75%    1670.500000  2020.000000
# max    2227.000000  2022.000000

# %%
f.notnull()
# Out:
#       Unnamed: 0  Country  iso2  iso3  Year  icd10n  icd103n  icd104n  icd10c  \
# 0           True     True  True  True  True    True     True     True    True
# 1           True     True  True  True  True    True     True     True    True
# 2           True     True  True  True  True    True     True     True    True
# 3           True     True  True  True  True    True     True     True    True
# 4           True     True  True  True  True    True     True     True    True
# ...          ...      ...   ...   ...   ...     ...      ...      ...     ...
# 2222        True     True  True  True  True    True     True     True    True
# 2223        True     True  True  True  True    True     True     True    True
# 2224        True     True  True  True  True    True     True     True    True
# 2225        True     True  True  True  True    True     True     True    True
# 2226        True     True  True  True  True    True     True     True    True
#
# ...

# %%
f1=f.dropna()
f1.isnull().sum()
# Out:
# Unnamed: 0    0
# Country       0
# iso2          0
# iso3          0
# Year          0
# icd10n        0
# icd103n       0
# icd104n       0
# icd10c        0
# icd103c       0
# icd104c       0
# icd11c1       0
# icd11c2       0
# icd11c3       0
# icd11l1       0
# icd11l2       0
# icd11l3       0
# Disease       0
# DONs          0
# Definition    0
# dtype: int64

# %%
f1=f1.drop_duplicates()
f1.head()
# Out:
#    Unnamed: 0      Country iso2 iso3  Year                          icd10n  \
# 2           3  Afghanistan   AF  AFG  1998  Intestinal infectious diseases
# 3           4  Afghanistan   AF  AFG  1999      Codes for special purposes
# 4           5  Afghanistan   AF  AFG  2000  Intestinal infectious diseases
# 5           6  Afghanistan   AF  AFG  2005  Intestinal infectious diseases
# 6           7  Afghanistan   AF  AFG  1999  Intestinal infectious diseases
#
#                                              icd103n  \
# 2                                            Cholera
# 3  Provisional assignment of new diseases of unce...
# 4                                            Cholera
# 5                                            Cholera
# 6                                            Cholera
#
#                                     icd104n   icd10c icd103c icd104c icd11c1  \
# 2                         Classical cholera  A00-A09     A00    A000       1
# ...

# %%
f1.head()
# Out:
#    Unnamed: 0      Country iso2 iso3  Year                          icd10n  \
# 2           3  Afghanistan   AF  AFG  1998  Intestinal infectious diseases
# 3           4  Afghanistan   AF  AFG  1999      Codes for special purposes
# 4           5  Afghanistan   AF  AFG  2000  Intestinal infectious diseases
# 5           6  Afghanistan   AF  AFG  2005  Intestinal infectious diseases
# 6           7  Afghanistan   AF  AFG  1999  Intestinal infectious diseases
#
#                                              icd103n  \
# 2                                            Cholera
# 3  Provisional assignment of new diseases of unce...
# 4                                            Cholera
# 5                                            Cholera
# 6                                            Cholera
#
#                                     icd104n   icd10c icd103c icd104c icd11c1  \
# 2                         Classical cholera  A00-A09     A00    A000       1
# ...

# %%
f1['Year'].plot(kind='box',vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
f1['Disease'].value_counts().plot(kind='pie',figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Disease'>

# %%
f1['Country'].value_counts().plot(kind='pie',figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
f1['icd103n'].value_counts().plot(kind='pie',figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='icd103n'>

# %%
f1['Disease'].nunique()
# Out:
# 59

# %%
f1['Country'].nunique()
# Out:
# 232

# %%
s.isnull().sum()
# Out:
# dateRep                                                          0
# day                                                              0
# month                                                            0
# year                                                             0
# cases                                                            0
# deaths                                                           0
# countriesAndTerritories                                          0
# geoId                                                          275
# countryterritoryCode                                           123
# popData2019                                                    123
# continentExp                                                     0
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000    2879
# dtype: int64

# %%
s2=s.dropna()

# %%
s2.isnull().sum()
# Out:
# dateRep                                                       0
# day                                                           0
# month                                                         0
# year                                                          0
# cases                                                         0
# deaths                                                        0
# countriesAndTerritories                                       0
# geoId                                                         0
# countryterritoryCode                                          0
# popData2019                                                   0
# continentExp                                                  0
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000    0
# dtype: int64

# %%
s2.count()
# Out:
# dateRep                                                       58759
# day                                                           58759
# month                                                         58759
# year                                                          58759
# cases                                                         58759
# deaths                                                        58759
# countriesAndTerritories                                       58759
# geoId                                                         58759
# countryterritoryCode                                          58759
# popData2019                                                   58759
# continentExp                                                  58759
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000    58759
# dtype: int64

# %%
ax=s['Unit_Cost'].plot(kind='hist', figsize=(14,6))
ax.set_ylabel('Number of Sales')
ax.set_xlabel('dollars')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.countplot(x='deaths',data=s2)
# Out:
# <AxesSubplot:xlabel='deaths', ylabel='count'>

# %%
s2.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...
