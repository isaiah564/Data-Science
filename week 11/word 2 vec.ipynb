# %%
import gensim.downloader as api
wv=api.load('word2vec-google-news-300')

# %%
for i, word in enumerate(wv.key_to_index):
    if i==10:
        break
        print(word)

# %%
vec_king=wv['king']
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
pairs=[
    ('car','minivan'),
    ('car','bicycle'),
    ('car','airplane'),
    ('car','cereal'),
    ('car','communism'),
]
for w1,w2 in pairs:
    print('%r\t%r\t%.2f'%(w1,w2,wv.similarity(w1,w2)))
# Out:
# 'car'	'minivan'	0.69
# 'car'	'bicycle'	0.54
# 'car'	'airplane'	0.42
# 'car'	'cereal'	0.14
# 'car'	'communism'	0.06

# %%
print(wv.most_similar(positive=['car','minivan'],topn=5))
# Out:
# [('SUV', 0.8532191514968872), ('vehicle', 0.8175783753395081), ('pickup_truck', 0.7763689160346985), ('Jeep', 0.7567334175109863), ('Ford_Explorer', 0.7565719485282898)]

# %%
print(wv.doesnt_match(['fire','water','land','sea','air','car']))
# Out:
# car

# %%
import json
import pandas as pd
import string
import time

# %%
data=[]

for line in open('C:\\Users\\Admin\\Desktop\\DataScience\\Datasets\\Cell_Phones_and_Accessories_5.json'):
    data.append(json.loads(line))

# %%
print(data[0])
df=pd.DataFrame(data)
print(len(data))
# Out:
# {'overall': 5.0, 'verified': True, 'reviewTime': '08 4, 2014', 'reviewerID': 'A24E3SXTC62LJI', 'asin': '7508492919', 'style': {'Color:': ' Bling'}, 'reviewerName': 'Claudia Valdivia', 'reviewText': 'Looks even better in person. Be careful to not drop your phone so often because the rhinestones will fall off (duh). More of a decorative case than it is protective, but I will say that it fits perfectly and securely on my phone. Overall, very pleased with this purchase.', 'summary': "Can't stop won't stop looking at it", 'unixReviewTime': 1407110400}
# 1128437

# %%
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True   08 4, 2014  A24E3SXTC62LJI  7508492919
# 1      5.0      True  02 12, 2014  A269FLZCB4GIPV  7508492919
# 2      3.0      True   02 8, 2014   AB6CHQWHZW4TV  7508492919
# 3      2.0      True   02 4, 2014   A1M117A53LEI8  7508492919
# 4      4.0      True   02 3, 2014  A272DUT8M88ZS8  7508492919
#
#                   style      reviewerName  \
# 0  {'Color:': ' Bling'}  Claudia Valdivia
# 1                   NaN       sarah ponce
# 2                   NaN               Kai
# 3                   NaN   Sharon Williams
# 4                   NaN   Bella Rodriguez
#
#                                           reviewText  \
# 0  Looks even better in person. Be careful to not...
# 1  When you don't want to spend a whole lot of ca...
# 2  so the case came on time, i love the design. I...
# 3  DON'T CARE FOR IT.  GAVE IT AS A GIFT AND THEY...
# 4  I liked it because it was cute, but the studs ...
#
# ...

# %%
df1=pd.DataFrame(df)
df=df.drop(columns=['reviewerName','vote','image','style'])

df1=df1.rename(columns={'overall':'rating','asin':'productID'})

# %%
print(df)
# Out:
#          rating  verified   reviewTime      reviewerID   productID  \
# 0           5.0      True   08 4, 2014  A24E3SXTC62LJI  7508492919
# 1           5.0      True  02 12, 2014  A269FLZCB4GIPV  7508492919
# 2           3.0      True   02 8, 2014   AB6CHQWHZW4TV  7508492919
# 3           2.0      True   02 4, 2014   A1M117A53LEI8  7508492919
# 4           4.0      True   02 3, 2014  A272DUT8M88ZS8  7508492919
# ...         ...       ...          ...             ...         ...
# 1128432     4.0      True  12 22, 2016  A1QWMCG1FNEP3A  B01HJC7N4C
# 1128433     5.0     False  07 15, 2016  A3FOBEJ9UVUTR3  B01HJC7N4C
# 1128434     5.0     False  07 14, 2016   AMUEAMKB4E33M  B01HJC7N4C
# 1128435     5.0     False  07 13, 2016  A2EV91MMOJ3IL4  B01HJC7N4C
# 1128436     5.0      True  05 11, 2017   ARKQD9Z1VPOV2  B01HJH9IN6
#
#                                                 reviewText  \
# 0        Looks even better in person. Be careful to not...
# ...

# %%
df1.dropna(axis=0,how='any',inplace=True)

# %%
df1.drop_duplicates(subset=['rating','reviewText'],keep='first')
# Out:
#          rating  verified   reviewTime      reviewerID   productID  \
# 638         4.0      True  11 13, 2015  A24Y8B3MAD57SZ  B0000DIDAH
# 909         4.0      True  12 23, 2016  A2K4Z2Q3ZSKQFB  B0002SYC5O
# 1307        5.0      True   05 5, 2008   APY2KYDHD8QIZ  B0006TIA8Y
# 4797        5.0      True  10 27, 2015  A21LX0AROD73W3  B000S5VI8A
# 5675        1.0      True  03 28, 2012   A8KWF1MFW7AXQ  B000WKQ8LS
# ...         ...       ...          ...             ...         ...
# 1126321     5.0      True  06 11, 2016  A2CHYIOTH5NN5Y  B01FPJZ58M
# 1126322     5.0     False   06 7, 2016  A3VE4IP1U4QBWO  B01FPJZ58M
# 1126613     5.0      True  12 10, 2017  A3A4T9PJBMS23F  B01FWD1T3Q
# 1126836     5.0     False  07 18, 2016  A2SFHFZHXAIWO6  B01G1RI5BQ
# 1126855     4.0     False  08 26, 2017  A2CHYIOTH5NN5Y  B01G2CD4CK
#
#                                                      style  reviewerName  \
# 638      {'Size:': ' Men's 46 mm', 'Color:': ' Black', ...   james avila
# ...

# %%
def clean_text(text):
    delete_dict={sp_characters:'' for sp_characters in string.punctuation}
    delete_dict['']=''
    table=str.maketrans(delete_dict)
    text1=text.translate(table)
    #print('cleaned:'+text)
    textArr=''.join([w for w in textArr if (not w.isdigit()and (not w.isdigit()))])
    
    return text2.lower().split('')

# %%
df2=df1.sample(n=2000)
df2['reviewText']=df2['reviewText'].apply(clean_text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 2
#       1 df2=df1.sample(n=2000)
# ----> 2 df2['reviewText']=df2['reviewText'].apply(clean_text)
#
# File ~\anaconda3\envs\py3-tf2\lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\envs\py3-tf2\lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# ...
